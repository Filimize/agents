# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
# openai_api_key = os.getenv('OPENAI_API_KEY')

# if openai_api_key:
#     print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
# else:
#     print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
    
api_key = os.getenv('API_KEY')
if api_key:
    print(f"The key exist and it is {api_key}")
else:
    print("Nope")
# Out:
# The key exist and it is Ollama

# %%
# !ollama pull llama3.2
# Out:
# pulling manifest ⠙ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

MODEL = "llama3.2"
openai = OpenAI(base_url="http://localhost:11434/v1", api_key="ollama")

# response = openai.chat.completions.create(
#  model=MODEL,
#  messages=[{"role": "user", "content": "What is 2 + 2?"}]
# )

# print(response.choices[0].message.content)

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

# openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
    model=MODEL,
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 = 4.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model= MODEL,
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# If a 16-year-old girl was born on February 12th, 2005, and died after being put into a stasis-induced coma for exactly 10 years without waking up, then what would be her exact date of death in a calendar that starts its year on January 1st?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model=MODEL,
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# To find the birthday day's difference between February 12th and January 1st, subtract that from 365.
#
# 365 - 43 (February) = 322
# 322 / 365 days/year ≈ .8822
#
# Now multiply this by her age in years.
#
# .8822 * 16 years is approximately equal to about .14 or 14/10 years.
#
# Her exact birthday's difference after her birthdate would be an approximate .14 or 16 / 10 years from February 12th = (43 - (14 + 2))
#
# So her birthday's date when she died, or when she finally went out of the stasis-induced coma and passed away on would be at roughly:
#
# 13th May

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# To find the birthday day's difference between February 12th and January 1st, subtract that from 365.
#
# 365 - 43 (February) = 322
# 322 / 365 days/year ≈ .8822
#
# Now multiply this by her age in years.
#
# .8822 * 16 years is approximately equal to about .14 or 14/10 years.
#
# Her exact birthday's difference after her birthdate would be an approximate .14 or 16 / 10 years from February 12th = (43 - (14 + 2))
#
# So her birthday's date when she died, or when she finally went out of the stasis-induced coma and passed away on would be at roughly:
#
# 13th May

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Can you pick a business idea that might be worth to explore for an Agentic AI oppotunity"}]

# Then make the first call:
# Ask it again
response = openai.chat.completions.create(
    model = MODEL,
    messages = messages
)
business_idea = response.choices[0].message.content
print(business_idea)

# Then read the business idea:
# And repeat! In the next message, include the business idea within the message
# Out:
# Based on the current development of Agentic AI, I'll suggest a business idea that leverages its potential to create value:
#
# **Business Idea:** "Augmentative Task Management Platform" for Large Enterprises
#
# **Description:**
# The platform would utilize Agentic AI to enable employees to autonomously complete tasks and projects with minimal supervision. This approach would aim to increase efficiency, productivity, and quality by harnessing the power of autonomous decision-making.
#
# **Key Features:**
#
# 1. **Task Assignment**: The platform uses natural language processing (NLP) and machine learning algorithms to analyze existing workflows, project requirements, and task dependencies.
# 2. **Autonomous Task Execution**: Agentic AI is used to execute tasks autonomously, using adaptive decision-making capabilities that learn from previous attempts, successes, and failures.
# 3. **Continuous Learning**: The platform's AI model iteratively updates its knowledge graph based on the performance of autonomous tasks, allowing for continuous learning and improvement.
# 4. **Real-time Feedback Loop**: A cloud-based interface enables workers to monitor their progress in real-time, providing instant feedback that refines future adaptive decisions.
# 5. **Integration with Existing Systems**: The platform would seamlessly integrate with popular project management tools (e.g., Asana, Trello) and productivity software (e.g., Microsoft Office) for cohesive workflow optimization.
#
# **Target Benefits:**
#
# 1. **Improved task completion rates**: Autonomous task execution leads to faster completion times.
# 2. **Enhanced quality control**: Agentic AI ensures consistency in result accuracy by learning from performance data.
# 3. **Reduced employee training time**: As autonomous task management takes hold, employees can focus on high-value tasks that require human expertise.
#
# **Agentic AI Opportunities:**
#
# 1. **Autonomous Task Scheduling**: Create customized task scheduling algorithms using Agentic AI to prioritize and manage workload distribution between humans and autonomous agents.
# 2. **Dynamic Process Optimization**: Incorporate Agentic AI to continuously analyze workflows and automatically optimize processes based on performance metrics.
#
# By exploiting the potential of Agentic AI, an innovative business model can unlock significant improvements in productivity, efficiency, and employee experience for large enterprises.
#
# This idea combines cutting-edge technology with practical value-driven applications that are relevant to everyday enterprise challenges.

# %%
messages = [{'role': "user", "content": "what are the pain-point in this industry"+business_idea}]
response = openai.chat.completions.create(
    model = MODEL,
    messages = messages
)
pain_point = response.choices[0].message.content
print(pain_point)
# Out:
# Based on the development of Agentic AI, here are some pain points in this industry that your "Augmentative Task Management Platform" aims to address:
#
# 1. **Task Management Complexity**: Traditional task management systems often lack flexibility and scalability, leading to inefficient workflows and increased labor costs.
#
# 2. **Information Overload**: Employees are bombarded with a massive amount of information from various sources, making it difficult for humans to make decisions without significant cognitive overload.
#
# 3. **Training Time for Employees**: New employees need significant training time to become productive, which can lead to high recruitment and onboarding costs.
#
# 4. **Quality Control Challenges**: Ensuring quality control in repetitive tasks has always been challenging due to human limitations such as distraction, fatigue, or personal bias.
#
# 5. **Business Process Inefficiency**: Large enterprises have complex, interdependent processes that require manual execution, resulting in wasted time, resources, and opportunities for improvement.
#
# 6. **Skillset Shortage**: With the emergence of new technologies, workers need specialized skills to work effectively with AI systems, creating a shortage of trained professionals.
#
# 7. **Scalability Challenges**: As organizations grow, their tasks, projects, and workflows increase exponentially, leading to inadequate task management systems that struggle to keep up.
#
# 8. **Resistance to Change**: Many employees and managers resist the adoption of new technologies, fearing it will change their way of working and potentially harm job security.
#
# 9. **Feedback Loops**: Gathering timely and actionable feedback is crucial for successful process optimization, but often falls short due to inadequate data collection, analysis, or communication methodologies.
#
# 10. **Integration with Existing Systems**: Seamlessly integrating Agentic AI tools into existing enterprise systems, such as project management tools or productivity software, has been a significant hurdle in the past.
#
# By developing an Augmentative Task Management Platform that tackles these industry pain points, your business can create a market need met and reap benefits from harnessing the potential of Agentic AI.

# %%
messages = [{'role': "user", "content": "Propose agentic AI solution to fix these pain point:" + pain_point}]
response = openai.chat.completions.create(
    model = MODEL,
    messages = messages
)
solution = response.choices[0].message.content
print(solution)
# Out:
# Introducing "Augma": An Augmentative Task Management Platform powered by Agentic AI, designed to tackle the industry's most pressing pain points.
#
# **Mission:**
# Embody the fusion of human and artificial intelligence to create a seamless workflow experience that enhances productivity, reduces errors, and fuels innovation.
#
# **Core Objectives:**
#
# 1. Simplify Task Management Complexity:
#    - Auto-generate customized workflows based on team structure, task dependencies, and organizational hierarchy.
#    - Provide real-time visibility into task status and allocation, enabling informed decision-making.
#
# 2. Manage Information Overload:
#    - Utilize AI-powered data filtering to prioritize important information for each employee, diminishing cognitive overload.
#    - Create a personal info hub, allowing users to easily access required information from various sources.
#
# 3. Accelerate Training Time for Employees:
#    - Develop Interactive Learning Paths through gamified training simulations and personalized mentorship models (AI-driven coaching).
#    - Real-time Analytics facilitates insights about the effectiveness of current training methods.
#
# 4. Enhance Quality Control:
#    - Implement AI-assisted data validation rules to identify anomalies in high-volume task processing.
#    - Introduce Smart Review Checks where expert feedback is analyzed on time-sensitive projects, reducing potential errors.
#
# 5. Optimize Business Process Inefficiencies:
#    - Uncover opportunities for process improvement through a self-discovery phase using predictive analytics and data insights provided by Agentic AI.
#    - Collaborative planning of future processes incorporates various stakeholders to ensure efficient knowledge sharing.
#
# 6. Foster Skillset Development for Future Workers:
#    - Introduce learning modules tailored to emerging technologies in continuous development, allowing participants adapt quicker to updates on existing tools.
#    - Develop workshops focusing on soft skill adaptation and interpersonal teamwork based on AI data analysis that showcases productivity barriers faced by modern workplaces.
#
# 7. Address Scalability Challenges:
#    - Expand modular workflows accommodating variable team sizes to optimize processing power with minimal degradation over time.
#    - Enable integration between current task management software through API support across different enterprise tools, providing broad compatibility.
#
# 8. Mitigate Resistance to Change:
#    - Foster trust and transparency in new systems by incorporating regular progress check-up sessions for feedback via video calls or meetings whenever needed.
#    - Highlight how adopting Agmatic solutions enhances job responsibility, personal growth, skill development for the future and encourages team cohesion through participation in brainstorming sessions involving the latest technological discoveries.
#
# 9. Optimize Feedback Loops:
#    - Utilize AI-driven data analysis tools that identify bottlenecks within feedback gathering processes to streamline suggestions from stakeholders directly into project management sections.
#    - Introduce an innovative, personalized communication network powered by sentiment analytics for employees and managers, enabling immediate resolutions on potential conflict and stress caused by inefficient processes.
#
# 10. Seamlessly Integrate with Existing Systems:
#     - Implement APIs across major ERP tools such as SAP & Oracle to simplify importing tasks from CRM records into the Augma platform seamlessly.
#     - Collaborate with industry partners in ongoing research and development of enhanced task management integrations through workshops designed for sharing data updates on both current systems and new emerging tools.
#
# **Strategic Advantage:** By focusing on the core pain points while integrating modernized features built upon Agentic AI, our goal is to establish Augma as the leader in augmentative task management solutions that harness its capabilities to drive more efficient workflows, boost productivity, minimize errors and contribute towards skill development among its workforce.
